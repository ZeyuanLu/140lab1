# %% [markdown]
# # Here we collects data and make plots:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
size=np.array([4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048])

# %% [markdown]
# The data is collected from executions

# %%
time1=np.array([0.001246,0.000838,0.001175,0.000657,0.001459,0.003075,0.016119,0.156496,1.709797,171.028093])

rate1=np.array([102731,1.2219e+06,6.97093e+06,9.97742e+07,3.59376e+08,1.36405e+09,2.08167e+09,1.71529e+09,1.25599e+09,1.00451e+08])

# %%
time2=np.array([0.000790,0.001074,0.001011,0.001370,0.001797,0.008368,0.098923,0.713065,7.095474,61.543801])

rate2=np.array([162050,953590,8.10371e+06,4.78381e+07,2.91764e+08,5.0123e+08,3.39198e+08,3.76453e+08,3.02655e+08,2.79149e+08])

# %%
time3=np.array([0.000720,0.001648,0.001222,0.001050,0.001832,0.005405,0.034301,0.177243,1.544468,210.283692])

rate3=np.array([177772,621378,6.70434e+06,6.24155e+07,2.86182e+08,7.75978e+08,9.78234e+08,1.51451e+09,1.39044e+09,8.16985e+07])

# %%
time4=np.array([0.001052,0.001381,0.001047,0.001239,0.001173,0.002016,0.009495,0.044852,0.206526,1.548985])

rate4=np.array([121684,741534,7.82326e+06,5.28917e+07,4.46956e+08,2.08044e+09,3.53399e+09,5.98491e+09,1.03981e+10,1.1091e+10])

# %%
time5=np.array([0.001873,0.000817,0.000938,0.001240,0.001429,0.007659,0.099026,0.724323,7.084126,62.913261])

rate5=np.array([68339,1.25364e+06,8.73405e+06,5.28611e+07,3.66871e+08,5.47634e+08,3.38844e+08,3.70602e+08,3.0314e+08,2.73072e+08])

# %%
time6=np.array([0.001645,0.000913,0.000762,0.000764,0.001087,0.001983,0.010661,0.054061,0.246467,2.623940])

rate6=np.array([77807.4,1.1214e+06,1.07509e+07,8.57653e+07,4.82348e+08,2.11521e+09,3.14743e+09,4.96542e+09,8.71306e+096.54736e+09])

# %% [markdown]
# # Question 1:

# %% [markdown]
# From observation of the executions, we find number 4 and 6 are the two fastest algorithm.

# %%
plt.rcParams["figure.figsize"] = [7.50, 4.5]
plt.rcParams["figure.autolayout"] = True
plt.plot(size,np.log(time4),color='blue',label='time4')
plt.plot(size,np.log(time6),color='cyan',label='time6')
plt.xlabel('side size')
plt.ylabel('log of time (log(t))')
plt.title('Graph problem size against log time taken for algorithm 4',fontweight ="bold")
plt.show()

# %% [markdown]
# # Question 2:
# Below is the plots of Graph problem size against $log$ of FLOPS for all algorithms

# %%
plt.rcParams["figure.figsize"] = [7.50, 4.5]
plt.rcParams["figure.autolayout"] = True


plt.plot(size,np.log(rate1),label='rate1',color='red')
plt.plot(size,np.log(rate2),label='rate2',color='purple')
plt.plot(size,np.log(rate3),label='rate3',color='green')
plt.plot(size,np.log(rate4),label='rate4',color='blue')
plt.plot(size,np.log(rate5),label='rate5',color='orange')
plt.plot(size,np.log(rate6),label='rate6',color='cyan')

plt.legend(loc='best',prop ={'size': 10})
plt.xlabel('side size')
plt.ylabel('log of FLOPS (log(FLOPS))')
plt.title('Graph problem size against FLOPS for all algorithms',fontweight ="bold")
plt.show()

# %% [markdown]
# # Question 3:
# From observation above, we can find fastest algorithm are number 4 and 6.\
# The slowest are number 1 and 3.\
# The little difference between 4,6 and 1,3 may be caused when running the program.
# Then,The plots are shown below.

# %%
plt.rcParams["figure.figsize"] = [7.50, 4.5]
plt.rcParams["figure.autolayout"] = True

plt.plot(size,np.log(rate1),label='rate1',color='red')
plt.plot(size,np.log(rate3),label='rate3',color='green')
plt.plot(size,np.log(rate4),label='rate4',color='blue')
plt.plot(size,np.log(rate6),label='rate6',color='cyan')


plt.legend(loc='lower right',prop ={'size': 10})
plt.xlabel('side size')
plt.ylabel('log of FLOPS (log(FLOPS))')
plt.title('Graph problem size against FLOPS for fastest and slowest algorithm',fontweight ="bold")
plt.show()
